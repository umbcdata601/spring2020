# %% [markdown]
# # how to accomplish the homework using Pandas
#
# Problem: doesn't preserve formulas and charts and formatting

# %%
import pandas
print('pandas',pandas.__version__)
# Out:
# pandas 0.23.4

# %%
# please use .head() or .tail() rather than viewing the entire dataframe
pandas.set_option("display.max_rows", 999)
pandas.set_option("display.max_columns", 999)

# %% [markdown]
# # load data

# %%
df_records=pandas.read_excel('week_05_homework_XLSX_openpyxl.xlsx',sheet_name='records')
df_records.shape
# Out:
# (1200, 29)

# %%
df_patientInfo=pandas.read_excel('week_05_homework_XLSX_openpyxl.xlsx',sheet_name='patient info')
df_patientInfo.shape
# Out:
# (772, 6)

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html

# %%
df = pandas.merge(df_patientInfo,df_records,
               left_on='patient id',right_on='p_id',how='outer')

# %%
df
# Out:
#       patient id   age  smoking  smart  asdf  min im     p_id     nam    kf  \
# 0        28859.0  25.0      1.0  109.0  25.0   40.00  28859.0  cvwrup  33.0
# 1        32820.0  48.0      1.0  112.0  29.0   47.50      NaN     NaN   NaN
# 2        32897.0  46.0      0.0  124.0  25.0   48.75      NaN     NaN   NaN
# 3        54826.0  49.0      1.0   76.0  38.0   41.00  54826.0  eqlxge  78.0
# 4        57378.0  57.0      1.0  137.0  36.0   57.75      NaN     NaN   NaN
# 5        70855.0  71.0      0.0   71.0  25.0   41.75      NaN     NaN   NaN
# 6        73709.0  57.0      0.0  141.0  40.0   59.50  73709.0  yqmswv  63.0
# 7        89507.0  33.0      1.0   72.0  34.0   35.00      NaN     NaN   NaN
# 8        98315.0  36.0      1.0  146.0  25.0   52.00      NaN     NaN   NaN
# 9        99668.0  33.0      0.0  118.0  21.0   43.00      NaN     NaN   NaN
# 10       21977.0  68.0      0.0   84.0  26.0   44.50  21977.0  jvciio  44.0
# ...
