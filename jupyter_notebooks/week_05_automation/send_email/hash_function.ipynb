# %% [markdown]
# https://docs.python.org/3/library/hashlib.html
#
# https://www.geeksforgeeks.org/md5-hash-python/

# %%
import hashlib

# %% [markdown]
# ## hash of file content

# %%
def md5_file(fname):
    return hashlib.md5(open(fname, "rb").read()).hexdigest()

# %%
md5_file = lambda x: hashlib.md5(open(x, "rb").read()).hexdigest()

# %%
md5_file('send_email/gmail_api.ipynb')
# Out:
# '7807c05c0fed4b833b98c8e8ef26876a'

# %% [markdown]
# ## hash of empty string

# %%
hashlib.md5().hexdigest()
# Out:
# 'd41d8cd98f00b204e9800998ecf8427e'

# %% [markdown]
# ## hash of string

# %%
hashlib.md5(b"Nobody inspects the spammish repetition").hexdigest()
# Out:
# 'bb649c83dd1ea5c9d9dec9a18df0ffe9'

# %%
m = hashlib.md5()
m.update(b"Nobody inspects the spammish repetition")
print (m.hexdigest())
# Out:
# bb649c83dd1ea5c9d9dec9a18df0ffe9
