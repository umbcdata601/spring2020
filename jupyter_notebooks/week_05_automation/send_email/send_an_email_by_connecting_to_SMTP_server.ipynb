# %% [markdown]
# https://www.pythonforbeginners.com/code-snippets-source-code/using-python-to-send-email
#
# https://medium.freecodecamp.org/send-emails-using-code-4fcea9df63f

# %%
import smtplib

# %% [markdown]
# specify the server we are interactin with

# %%
#server.connect("smtp.gmail.com",587)#465)
#server = smtplib.SMTP('smtp.gmail.com', 587)
server = smtplib.SMTP('smtp.gmail.com:587')

# %% [markdown]
# SMTP protocol (see https://www.ietf.org/rfc/rfc2821.txt) requires starting with a `ehlo` command

# %%
server.ehlo()
# Out:
# (250,
#  b'smtp.gmail.com at your service, [130.85.253.6]\nSIZE 35882577\n8BITMIME\nSTARTTLS\nENHANCEDSTATUSCODES\nPIPELINING\nCHUNKING\nSMTPUTF8')

# %% [markdown]
# we use TLS (https://en.wikipedia.org/wiki/Transport_Layer_Security) for security

# %%
server.starttls()
# Out:
# (220, b'2.0.0 Ready to start TLS')

# %% [markdown]
# when we send `ehlo` this time, we get a secure login message

# %%
server.ehlo()
# Out:
# (250,
#  b'smtp.gmail.com at your service, [130.85.253.6]\nSIZE 35882577\n8BITMIME\nSTARTTLS\nENHANCEDSTATUSCODES\nPIPELINING\nCHUNKING\nSMTPUTF8')

# %% [markdown]
# Log into the server using email and password credentials

# %%
server.login("myemail@thedomain.com", "passwrd")
# Out:
# ---------------------------------------------------------------------------
# SMTPAuthenticationError                   Traceback (most recent call last)
# <ipython-input-6-71f1b3255e79> in <module>
# ----> 1 server.login("myemail@thedomain.com", "passwrd")
#
# /opt/conda/lib/python3.6/smtplib.py in login(self, user, password, initial_response_ok)
#     728
#     729         # We could not login successfully.  Return result of last attempt.
# --> 730         raise last_exception
#     731
#     732     def starttls(self, keyfile=None, certfile=None, context=None):
#
# /opt/conda/lib/python3.6/smtplib.py in login(self, user, password, initial_response_ok)
#     719                 (code, resp) = self.auth(
#     720                     authmethod, getattr(self, method_name),
# --> 721                     initial_response_ok=initial_response_ok)
#     722                 # 235 == 'Authentication successful'
#     723                 # 503 == 'Error: already authenticated'
#
# /opt/conda/lib/python3.6/smtplib.py in auth(self, mechanism, authobject, initial_response_ok)
#     640         if code in (235, 503):
#     641             return (code, resp)
# --> 642         raise SMTPAuthenticationError(code, resp)
#     643
#     644     def auth_cram_md5(self, challenge=None):
#
# SMTPAuthenticationError: (535, b'5.7.8 Username and Password not accepted. Learn more at\n5.7.8  https://support.google.com/mail/?p=BadCredentials b22sm78772qkc.58 - gsmtp')

# %% [markdown]
# Gmail doesn't allow username and password login for SMTP
#
# If the server does accept that method, we use the following commands to send email:

# %%
text = msg.as_string()

# %%
fromaddr='myemail@serv.com'
toaddr  ='dest@anot.org'
server.sendmail(fromaddr, toaddr, text)
server.quit()

#Send the mail
msg = "Hello!" # The /n separates the message from the headers
server.sendmail("you@gmail.com", "target@example.com", msg)
