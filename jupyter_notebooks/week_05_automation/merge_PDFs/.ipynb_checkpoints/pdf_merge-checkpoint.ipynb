# %%
# !pip install PyPDF2

# %%
from PyPDF2 import PdfFileMerger, PdfFileReader

# %%
# !rm merge-pdfs.pdf

# %% [markdown]
# Now there's nothing up my sleeves:

# %%
# !ls *.pdf

# %% [markdown]
# I like easy to use Python libraries

# %%
mergr=PdfFileMerger()
mergr.append(PdfFileReader("My-Page-Profile-22-1753.pdf", 'rb'))
mergr.append(PdfFileReader("horizonbook-one-page-template.pdf", 'rb'))
with open('merge-pdfs.pdf', 'wb') as f:
    mergr.write(f)

# %% [markdown]
# The newly created PDF:

# %%
# !ls
