# %% [markdown]
# Create a property graph of the files on folders in a given folder

# %%
# !pip install graphviz
# Out:
# Requirement already satisfied: graphviz in /opt/conda/lib/python3.6/site-packages (0.13.2)

# %%
import glob

# %% [markdown]
# https://stackoverflow.com/questions/2186525/use-a-glob-to-find-files-recursively-in-python

# %%
for filename in glob.iglob('./**/*', recursive=True):
    print(filename)
# Out:
# ./graphviz_for_static_directed_graph_visualization.ipynb
# ./lanl_netflow_activity.ipynb
# ./example1_graph.png
# ./py2neo.ipynb
# ./week_12_notebooks.zip
# ./not_used
# ./lanl_windows_logs.ipynb
# ./files_and_folders.ipynb
# ./samplefile.txt
# ./test-output
# ./print_to_file.ipynb
# ./networkx.ipynb
# ./graph_of_site_links.ipynb
# ./lanl_netflow.ipynb
# ./netflow_day_02_1E6rows.pkl
# ./lanl_netflow_activity.ipynb.zip
# ./graphviz_for_static_graph_visualization.ipynb
# ./pycallgraph.png
# ./py2neo_nepotism.ipynb
# ./pycallgraph.ipynb
# ./not_used/source.csv
# ./not_used/index.html
# ./not_used/marvel_characters.ipynb
# ./not_used/hero-network.csv.source
# ./not_used/source.csv.source
# ./not_used/hero-network.csv
# ./test-output/parrot.png
# ./test-output/filename.png
# ./test-output/files_and_folders
# ./test-output/fld_test.png
# ./test-output/round-table
# ./test-output/fld_test
# ./test-output/round-table.png
# ./test-output/files_and_folders.png
# ./test-output/parrot
# ./test-output/filename

# %% [markdown]
# glob doesn't support hidden directories :(
#
# https://docs.python.org/3/library/glob.html
#
# <BR>
# <BR>
# <BR>
#
# So instead recursively enter every directory
#
# https://stackoverflow.com/questions/9727673/list-directory-tree-structure-in-python

# %%
import os

def list_files(startpath):
    for root, dirs, files in os.walk(startpath):
        level = root.replace(startpath, '').count(os.sep)
        indent = ' ' * 4 * (level)
        print('{}{}/'.format(indent, os.path.basename(root)))
        subindent = ' ' * 4 * (level + 1)
        for f in files:
            print('{}{}'.format(subindent, f))

# %%
list_files('.')
# Out:
# ./
#     graphviz_for_static_directed_graph_visualization.ipynb
#     lanl_netflow_activity.ipynb
#     example1_graph.png
#     py2neo.ipynb
#     week_12_notebooks.zip
#     lanl_windows_logs.ipynb
#     files_and_folders.ipynb
#     samplefile.txt
#     print_to_file.ipynb
#     networkx.ipynb
#     graph_of_site_links.ipynb
#     lanl_netflow.ipynb
#     netflow_day_02_1E6rows.pkl
#     lanl_netflow_activity.ipynb.zip
#     graphviz_for_static_graph_visualization.ipynb
#     pycallgraph.png
#     py2neo_nepotism.ipynb
#     pycallgraph.ipynb
#     not_used/
#         source.csv
#         index.html
#         marvel_characters.ipynb
#         hero-network.csv.source
#         source.csv.source
#         hero-network.csv
#     test-output/
#         parrot.png
#         filename.png
#         files_and_folders
#         fld_test.png
#         round-table
#         fld_test
#         round-table.png
#         files_and_folders.png
#         parrot
#         filename
#     .ipynb_checkpoints/
#         files_and_folders-checkpoint.ipynb
#         py2neo_nepotism-checkpoint.ipynb
#         graphviz_for_static_directed_graph_visualization-checkpoint.ipynb
#         lanl_netflow_activity-checkpoint.ipynb
#         lanl_netflow-checkpoint.ipynb
#         print_to_file-checkpoint.ipynb
#         graph_of_site_links-checkpoint.ipynb
#         pycallgraph-checkpoint.ipynb
#         networkx-checkpoint.ipynb
#         graphviz_for_static_graph_visualization-checkpoint.ipynb

# %% [markdown]
# https://www.quora.com/Whats-the-easiest-way-to-recursively-get-a-list-of-all-the-files-in-a-directory-tree-in-Python
#
# This yields information equivalent to <BR>
# !find

# %%
from os import walk
path ="." # current directory
for (dirpath, dirnames, filenames) in walk(path):
    print('current location:',dirpath)
    print('folders:         ',dirnames)
    print('files:           ',filenames,'\n')
# Out:
# current location: .
# folders:          ['not_used', 'test-output', '.ipynb_checkpoints']
# files:            ['graphviz_for_static_directed_graph_visualization.ipynb', 'lanl_netflow_activity.ipynb', 'example1_graph.png', 'py2neo.ipynb', 'week_12_notebooks.zip', 'lanl_windows_logs.ipynb', 'files_and_folders.ipynb', 'samplefile.txt', 'print_to_file.ipynb', 'networkx.ipynb', 'graph_of_site_links.ipynb', 'lanl_netflow.ipynb', 'netflow_day_02_1E6rows.pkl', 'lanl_netflow_activity.ipynb.zip', 'graphviz_for_static_graph_visualization.ipynb', 'pycallgraph.png', 'py2neo_nepotism.ipynb', 'pycallgraph.ipynb']
#
# current location: ./not_used
# folders:          []
# files:            ['source.csv', 'index.html', 'marvel_characters.ipynb', 'hero-network.csv.source', 'source.csv.source', 'hero-network.csv']
#
# current location: ./test-output
# folders:          []
# files:            ['parrot.png', 'filename.png', 'files_and_folders', 'fld_test.png', 'round-table', 'fld_test', 'round-table.png', 'files_and_folders.png', 'parrot', 'filename']
#
# current location: ./.ipynb_checkpoints
# folders:          []
# files:            ['files_and_folders-checkpoint.ipynb', 'py2neo_nepotism-checkpoint.ipynb', 'graphviz_for_static_directed_graph_visualization-checkpoint.ipynb', 'lanl_netflow_activity-checkpoint.ipynb', 'lanl_netflow-checkpoint.ipynb', 'print_to_file-checkpoint.ipynb', 'graph_of_site_links-checkpoint.ipynb', 'pycallgraph-checkpoint.ipynb', 'networkx-checkpoint.ipynb', 'graphviz_for_static_graph_visualization-checkpoint.ipynb']

# %% [markdown]
# For more complicated view, look at the parent directory

# %%
from graphviz import Digraph, Graph

# %%
fld = Digraph(comment='files and folders')

# %%
fld.clear()

# %%
fld.node('/full/path/to/fldr', 'fldr')
fld.node('B', 'Sir Bedevere the Wise')
fld.node('L', 'Sir Lancelot the Brave')

fld.edge('B', 'L')
fld.edge('B', '/full/path/to/fldr')

# %%
print(fld.source)
# Out:
# // files and folders
# digraph {
# 	"/full/path/to/fldr" [label=fldr]
# 	B [label="Sir Bedevere the Wise"]
# 	L [label="Sir Lancelot the Brave"]
# 	B -> L
# 	B -> "/full/path/to/fldr"
# }

# %%
fld.format = 'png'
fld.render('test-output/fld_test', view=True)
# Out:
# 'test-output/fld_test.png'

# %%
from IPython.display import Image
Image("test-output/fld_test.png")

# %%
fld.clear()

path ="." # current directory
for (dirpath, dirnames, filenames) in walk(path):
    fld.node(dirpath, dirpath) # current location
    for this_subfolder in dirnames:
        fld.node(dirpath+'/'+this_subfolder, this_subfolder)
        fld.edge(dirpath, dirpath+'/'+this_subfolder)
    for this_file in filenames:
        fld.node(dirpath+'/'+this_file, this_file)
        fld.edge(dirpath, dirpath+'/'+this_file)

# %%
#print(fld.source)

# %%
fld.format = 'png'
fld.render('test-output/files_and_folders', view=True)
# Out:
# 'test-output/files_and_folders.png'

# %%
Image("test-output/files_and_folders.png")

# %%
fld.graph_attr['rankdir'] = 'LR'
fld.render('test-output/files_and_folders', view=True)
Image("test-output/files_and_folders.png")

# %%
fld.engine = 'circo'
fld.render('test-output/files_and_folders', view=True)
Image("test-output/files_and_folders.png")

# %%
fld.engine = 'neato'#'twopi'
fld.attr(overlap='false')
fld.render('test-output/files_and_folders', view=True)
Image("test-output/files_and_folders.png")
