# %% [markdown]
# https://itsharveytime.com/2014/06/03/using-cprofile-with-python/
#
# .py source file:<BR>
# https://github.com/mondejar/ecg-classification/tree/master/python<BR>
# https://raw.githubusercontent.com/mondejar/ecg-classification/master/python/run_train_SVM.py

# %%
# !python -m cProfile -s cumulative run_train_SVM.py
# Out:
#          789556 function calls (772643 primitive calls) in 31.883 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    1464/1    0.199    0.000   31.910   31.910 {built-in method builtins.exec}
#         1    0.000    0.000   31.910   31.910 run_train_SVM.py:9(<module>)
#    1363/1    0.185    0.000   31.910   31.910 <frozen importlib._bootstrap>:966(_find_and_load)
#    1363/1    0.143    0.000   31.910   31.910 <frozen importlib._bootstrap>:936(_find_and_load_unlocked)
#    1231/1    0.166    0.000   31.903   31.903 <frozen importlib._bootstrap>:651(_load_unlocked)
#    1078/1    0.076    0.000   31.902   31.902 <frozen importlib._bootstrap_external>:672(exec_module)
#    1656/1    0.068    0.000   31.891   31.891 <frozen importlib._bootstrap>:211(_call_with_frames_removed)
#         1    0.000    0.000   31.891   31.891 train_SVM.py:9(<module>)
# ...
