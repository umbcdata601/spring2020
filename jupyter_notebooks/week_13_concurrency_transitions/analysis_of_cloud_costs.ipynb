# %%
import glob 
import pandas

# %%
pandas.set_option('display.max_rows', 500)
pandas.set_option('display.max_columns', 500)

# %%
list_of_xlsx = glob.glob('week*.xlsx')

# %%
list_of_xlsx[0]
# Out:
# 'week 13 - survey of cloud costs_Anonymous Student (Attempt ID  15926429)_attempt_2019-04-30-18-24-33_week_13_CSP_survey.xlsx'

# %%
list_of_df=[]
for fil in list_of_xlsx:
    df = pandas.read_excel(fil)
    print('df.shape=',df.shape)
    list_of_df.append(df)
# Out:
# df.shape= (7, 4)
# df.shape= (7, 4)
# df.shape= (7, 4)
# df.shape= (7, 4)
# df.shape= (7, 4)
# df.shape= (7, 4)
# df.shape= (7, 4)
# df.shape= (10, 4)
# df.shape= (9, 4)
# df.shape= (30, 4)
# df.shape= (7, 4)
# df.shape= (7, 4)
# df.shape= (7, 4)
# df.shape= (7, 4)
# df.shape= (7, 4)
# df.shape= (7, 4)
# df.shape= (7, 4)
# df.shape= (7, 4)

# %%
list_of_df[7].shape
# Out:
# (10, 4)

# %%
list_of_df[7]
# Out:
#                                                 Vendor  \
# NaN                                                NaN
# NaN                                             aspect
# NaN                           storage: 1 TB for 1 year
# NaN                         storage: 100 TB for 1 year
# NaN              compute: 20 cores, 1TB of RAM, 5 GPUs
# NaN                                 data upload: 10 TB
# NaN                               data download: 10 TB
# NaN                                                NaN
# NaN                                  Learning Lesson?
# NaN  Pricing can be quite confusing and daunting ho...
#
#                                              Microsoft  \
# NaN                                                NaN
# NaN                                               cost
# NaN                                             737.28
# NaN                                              73728
# NaN                         8561.53 at least per month
# ...

# %%
print(list_of_df[8].shape)
list_of_df[8]
# Out:
# (9, 4)
#                                               Vendor   Google  \
# NaN  All pricing using Northern Virgina Region Rates      NaN
# NaN    Compute pricing using 1 year commitment price      NaN
# NaN                                              NaN      NaN
# NaN                                           aspect     cost
# NaN                         storage: 1 TB for 1 year   282.62
# NaN                       storage: 100 TB for 1 year  28262.4
# NaN            compute: 20 cores, 1TB of RAM, 5 GPUs  47689.4
# NaN                               data upload: 10 TB     free
# NaN                             data download: 10 TB  1136.64
#
#                                    Unnamed: 2  \
# NaN                                       NaN
# NaN                                       NaN
# NaN                                       NaN
# NaN                                source URL
# NaN  https://cloud.google.com/storage/pricing
# NaN  https://cloud.google.com/storage/pricing
# ...

# %%
print(list_of_df[9].shape)
list_of_df[9]
# Out:
# (30, 4)
#                                                 Vendor  \
# NaN                                                NaN
# NaN                                             Aspect
# NaN  Intel Xeon Gold 6148 Processor - 20 Cores, 2.4...
# NaN  Storage: 8x 2.4TB Enterprise Performance 10k 1...
# NaN  1 TB of RAM - 8x 128GB 2666MHz DDR4 LR ECC DIM...
# NaN  5 GPUs - 5x NVIDIA RTX 2070 Graphics Card PCI-...
# NaN  Storage: 120 TB - Synology RS2418+ RackStation...
# NaN                           storage: 1 TB for 1 year
# NaN                         storage: 100 TB for 1 year
# NaN                                            Compute
# NaN                                 data upload: 10 TB
# NaN                               data download: 10 TB
# NaN                                              Total
# NaN                                                NaN
# NaN                                                NaN
# NaN                                                NaN
# ...

# %%
list_of_df=[]
for fil in list_of_xlsx:
    df = pandas.read_excel(fil)
    print('df.shape=',df.shape)
    if df.shape[0]==7:
        list_of_df.append(df)
# Out:
# df.shape= (7, 4)
# df.shape= (7, 4)
# df.shape= (7, 4)
# df.shape= (7, 4)
# df.shape= (7, 4)
# df.shape= (7, 4)
# df.shape= (7, 4)
# df.shape= (10, 4)
# df.shape= (9, 4)
# df.shape= (30, 4)
# df.shape= (7, 4)
# df.shape= (7, 4)
# df.shape= (7, 4)
# df.shape= (7, 4)
# df.shape= (7, 4)
# df.shape= (7, 4)
# df.shape= (7, 4)
# df.shape= (7, 4)

# %%
all_df = pandas.concat(list_of_df,sort=False)
print(all_df.shape)
all_df.head()
# Out:
# (105, 15)
#                                     Vendor Amazon Cloud Services  \
# NaN                                    NaN                   NaN
# NaN                                 aspect                  cost
# NaN               storage: 1 TB for 1 year                  23 $
# NaN             storage: 100 TB for 1 year                2250 $
# NaN  compute: 20 cores, 1TB of RAM, 5 GPUs            80649.68 $
#
#                                          Unnamed: 2  \
# NaN                                             NaN
# NaN                                      source URL
# NaN              https://aws.amazon.com/s3/pricing/
# NaN              https://aws.amazon.com/s3/pricing/
# NaN  https://calculator.s3.amazonaws.com/index.html
#
#                                             Unnamed: 3 Self-Hosted Server  \
# NaN                                                NaN                NaN
# NaN                                               note                NaN
# ...

# %%
all_df.sort_values(by=['Vendor'])
# Out:
#                                         Vendor Amazon Cloud Services  \
# NaN                                     aspect                  cost
# NaN                                     aspect                   NaN
# NaN                                     aspect                   NaN
# NaN                                     aspect                   NaN
# NaN                                     aspect                   NaN
# NaN                                     aspect                   NaN
# NaN                                     aspect                   NaN
# NaN                                     aspect                   NaN
# NaN                                     aspect                   NaN
# NaN                                     aspect                   NaN
# NaN                                     aspect                   NaN
# NaN                                     aspect                   NaN
# NaN                                     aspect                   NaN
# ...

# %%
list_of_df=[]
for fil in list_of_xlsx:
    df = pandas.read_excel(fil)
    print('df.shape=',df.shape)
    if df.shape[0]==7:
        print(df)
# Out:
# df.shape= (7, 4)
#                                     Vendor Amazon Cloud Services  \
# NaN                                    NaN                   NaN
# NaN                                 aspect                  cost
# NaN               storage: 1 TB for 1 year                  23 $
# NaN             storage: 100 TB for 1 year                2250 $
# NaN  compute: 20 cores, 1TB of RAM, 5 GPUs            80649.68 $
# NaN                     data upload: 10 TB                   0 $
# NaN                   data download: 10 TB    899.91 $ per month
#
#                                          Unnamed: 2  \
# NaN                                             NaN
# NaN                                      source URL
# NaN              https://aws.amazon.com/s3/pricing/
# NaN              https://aws.amazon.com/s3/pricing/
# NaN  https://calculator.s3.amazonaws.com/index.html
# NaN              https://aws.amazon.com/s3/pricing/
# NaN              https://aws.amazon.com/s3/pricing/
#
# ...
