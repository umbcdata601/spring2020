# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html
#
# https://matplotlib.org/tutorials/introductory/pyplot.html

# %%
import time
import matplotlib.pyplot as plt
import pandas
print('Pandas',pandas.__version__)
# Out:
# Pandas 0.23.4

# %% [markdown]
# # load the data into a dataframe

# %%
start_time = time.time()
loans_2007 = pandas.read_csv('https://github.com/yhat/demo-lending-club/blob/master/model/LoanStats3a.csv?raw=true', 
                             skiprows=1, low_memory=False)
print(time.time() - start_time,'seconds')

# %% [markdown]
# how big is the 41MB table?

# %%
loans_2007.shape
# Out:
# (42535, 102)

# %%
loans_2007.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'apr', 'int_rate', 'installment', 'grade',
#        ...
#        'num_il_tl', 'mo_sin_old_il_acct', 'num_actv_rev_tl',
#        'mo_sin_old_rev_tl_op', 'mo_sin_rcnt_rev_tl_op', 'total_rev_hi_lim',
#        'num_rev_tl_bal_gt_0', 'num_op_rev_tl', 'tot_coll_amt', 'policy_code'],
#       dtype='object', length=102)

# %%
loans_2007.dtypes
# Out:
# id                               int64
# member_id                        int64
# loan_amnt                        int64
# funded_amnt                      int64
# funded_amnt_inv                float64
# term                            object
# apr                             object
# int_rate                        object
# installment                    float64
# grade                           object
# sub_grade                       object
# emp_name                        object
# emp_length                      object
# home_ownership                  object
# annual_inc                     float64
# is_inc_v                          bool
# accept_d                        object
# exp_d                           object
# list_d                          object
# issue_d                         object
# loan_status                     object
# pymnt_plan                      object
# url                             object
# desc                            object
# ...

# %%
loans_2007['id'].hist()

# %% [markdown]
# # visualize all the numeric columns

# %%
loans_2007.hist()
plt.show()

# %% [markdown]
# restructure that into a single column of histograms

# %%
_=loans_2007.hist(layout=(76,1))

# %% [markdown]
# Need to make the dimensions of the "one picture" very tall

# %%
list_of_figs=loans_2007.hist(layout=(76,1))
#plt.figure(figsize=(5,30))

# %%
len(list_of_figs)
# Out:
# 76

# %%
list_of_figs[0][0]
#plt.show()

# %%
for this_col in loans_2007.columns:
    print(this_col)
    print(loans_2007[this_col].dtype)
    loans_2007[this_col].hist()
    plt.show()
# Out:
# id
# int64
# member_id
# int64
# loan_amnt
# int64
# funded_amnt
# int64
# funded_amnt_inv
# float64
# term
# object
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-a2110691089a> in <module>
#       2     print(this_col)
#       3     print(loans_2007[this_col].dtype)
# ----> 4     loans_2007[this_col].hist()
#       5     plt.show()
#
# /opt/conda/lib/python3.6/site-packages/pandas/plotting/_core.py in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, **kwds)
#    2479         values = self.dropna().values
#    2480
# -> 2481         ax.hist(values, bins=bins, **kwds)
#    2482         ax.grid(grid)
#    2483         axes = np.array([ax])
#
# /opt/conda/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
for this_col in loans_2007.columns:
    print(this_col,loans_2007[this_col].dtype,loans_2007[this_col].nunique())
#    loans_2007[this_col].hist()
#    plt.show()
#loans_2007[this_col].value_counts().plot(kind='bar')
# Out:
# id int64 42535
# member_id int64 42535
# loan_amnt int64 898
# funded_amnt int64 1051
# funded_amnt_inv float64 9271
# term object 2
# apr object 737
# int_rate object 394
# installment float64 16458
# grade object 7
# sub_grade object 35
# emp_name object 30658
# emp_length object 11
# home_ownership object 5
# annual_inc float64 5597
# is_inc_v bool 2
# accept_d object 1626
# exp_d object 1625
# list_d object 1625
# issue_d object 1143
# loan_status object 13
# pymnt_plan object 2
# url object 42535
# desc object 28963
# purpose object 14
# title object 21264
# addr_city object 11378
# addr_state object 50
# acc_now_delinq float64 2
# acc_open_past_24mths float64 0
# bc_open_to_buy float64 0
# percent_bc_gt_75 float64 0
# bc_util float64 0
# dti float64 2894
# delinq_2yrs float64 12
# delinq_amnt float64 3
# earliest_cr_line object 42180
# fico_range_low int64 44
# fico_range_high int64 44
# inq_last_6mths float64 28
# mths_since_last_delinq float64 95
# ...
