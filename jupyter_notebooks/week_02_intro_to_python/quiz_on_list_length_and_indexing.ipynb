# %% [markdown]
# Given a list

# %%
my_list = ['a', 'b', 'c', 'd']

# %% [markdown]
# What does `len(my_list)` return?
# <BR>
# <BR>
# <BR>
# <BR>
# <BR>
# <BR>
# <BR>
# <BR>
# <BR>
# <BR>
# <BR>
# <BR>
# <BR>
# <BR>
# <BR>
# <BR>

# %%
len(my_list)

# %%
print(my_list)

# %% [markdown]
# What does `my_list[1]` return?
# <BR>
# <BR>
# <BR>
# <BR>
# <BR>
# <BR>
# <BR>
# <BR>
# <BR>
# <BR>
# <BR>
# <BR>
# <BR>
# <BR>
# <BR>
# <BR>
# <BR>
# <BR>

# %%
my_list[1]

# %%
print(my_list)
