# %% [markdown]
# create synthentic periodic data, similar to https://github.com/joke2k/faker
#
# https://github.com/TimeSynth/TimeSynth
#
#
# Parameters: # from https://github.com/TimeSynth/TimeSynth/blob/master/timesynth/signals/pseudoperiodic.py
# * amplitude : number (default 1.0) # Amplitude of the harmonic series
# * frequency : number (default 1.0) # Frequency of the harmonic series
# * ampSD : number (default 0.1) # Amplitude standard deviation
# * freqSD : number (default 0.1) # Frequency standard deviation
# * ftype : function(default np.sin) # Harmonic function

# %%
import timesynth as ts
# Initializing TimeSampler
time_sampler = ts.TimeSampler(stop_time=20)

# %%
import matplotlib.pyplot as plt

# %%
# Sampling irregular time samples
irregular_time_samples = time_sampler.sample_irregular_time(num_points=500, keep_percentage=50)
# Initializing Sinusoidal signal
sinusoid = ts.signals.Sinusoidal(frequency=0.25)
# Initializing Gaussian noise
white_noise = ts.noise.GaussianNoise(std=0.3)
# Initializing TimeSeries class with the signal and noise objects
timeseries = ts.TimeSeries(sinusoid, noise_generator=white_noise)
# Sampling using the irregular time samples
samples, signals, errors = timeseries.sample(irregular_time_samples)

# %%
_=plt.scatter(range(irregular_time_samples.shape[0]),irregular_time_samples)

# %%
samples.shape
# Out:
# (250,)

# %%
signals.shape
# Out:
# (250,)

# %%
errors.shape
# Out:
# (250,)

# %%
_=plt.scatter(range(samples.shape[0]),samples)

# %%
_=plt.scatter(irregular_time_samples,samples)

# %%
_=plt.scatter(range(signals.shape[0]),signals)

# %%
_=plt.scatter(range(errors.shape[0]),errors)
